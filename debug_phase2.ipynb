# %%
# %matplotlib inline
import os
os.environ['THEANO_FLAGS'] = "mode=FAST_RUN,device=cpu,floatX=float32"
import theano
import theano.tensor as T
import config
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Library/Python/2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import network
import network.normFlow as nf
import utils
import utils.mathT as mathT
import utils.theanoGeneral as utilsT
import utils.optimizers as optimizers
import utils.plotZ as plotZ
import models.mars as model

# %%
# learning how to use theano.tensor.switch

a = T.fmatrices('a')
z = T.switch( a>3, a, 5  )
fz = theano.function([a],outputs=z)

# %%
print fz( np.asarray([[2,3,4],[5,6,7]],dtype='float32'))
# Out:
# [[ 5.  5.  4.]
#  [ 5.  6.  7.]]

# %%
DIM = 2
SAMPLINGNUM = 30
floatX = utils.floatX

x = utilsT.sharedf(2)
z = T.fmatrix()

# constructing graphical model
mb = model.Banana()
mb.setX(3)
# setting cost variable
logpxz = mb.logPxz(z)
logpz  = mb.logPrior(z)

# %%
f1 = theano.function([],outputs=logpxz)
f2 = theano.function([],outputs=logpz)
# Out:
# ---------------------------------------------------------------------------
# MissingInputError                         Traceback (most recent call last)
# <ipython-input-6-a1740c534ed9> in <module>()
# ----> 1 f1 = theano.function([],outputs=logpxz)
#       2 f2 = theano.function([],outputs=logpz)
#
# /Library/Python/2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /Library/Python/2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /Library/Python/2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1774                    profile=profile,
#    1775                    on_unused_input=on_unused_input,
# -> 1776                    output_keys=output_keys).create(
#    1777             defaults)
#    1778
#
# /Library/Python/2.7/site-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1426             # OUTPUT VARIABLES)
#    1427             fgraph, additional_outputs = std_fgraph(inputs, outputs,
# -> 1428                                                     accept_inplace)
#    1429             fgraph.profile = profile
#    1430         else:
#
# /Library/Python/2.7/site-packages/theano/compile/function_module.pyc in std_fgraph(input_specs, output_specs, accept_inplace)
#     175
#     176     fgraph = gof.fg.FunctionGraph(orig_inputs, orig_outputs,
# --> 177                                   update_mapping=update_mapping)
#     178
#     179     for node in fgraph.apply_nodes:
#
# /Library/Python/2.7/site-packages/theano/gof/fg.pyc in __init__(self, inputs, outputs, features, clone, update_mapping)
#     169
#     170         for output in outputs:
# --> 171             self.__import_r__(output, reason="init")
#     172         for i, output in enumerate(outputs):
#     173             output.clients.append(('output', i))
#
# /Library/Python/2.7/site-packages/theano/gof/fg.pyc in __import_r__(self, variable, reason)
#     358         # Imports the owners of the variables
#     359         if variable.owner and variable.owner not in self.apply_nodes:
# --> 360                 self.__import__(variable.owner, reason=reason)
#     361         if (variable.owner is None and
#     362                 not isinstance(variable, graph.Constant) and
#
# /Library/Python/2.7/site-packages/theano/gof/fg.pyc in __import__(self, apply_node, check, reason)
#     472                             "for more information on this error."
#     473                             % str(node)),
# --> 474                             r)
#     475
#     476         for node in new_nodes:
#
# MissingInputError: ("An input of the graph, used to compute Prod{axis=[1], acc_dtype=float64}(<TensorType(float32, matrix)>), was not provided and not given a value.Use the Theano flag exception_verbosity='high',for more information on this error.", <TensorType(float32, matrix)>)

# %%
zsamples = np.asarray([[0,0],[1,2]],dtype=floatX)
xsamples = np.asarray([[0]],dtype=floatX)
print f1(xsamples,zsamples)
print f2(zsamples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f83696bd4e0e> in <module>()
#       1 zsamples = np.asarray([[0,0],[1,2]],dtype=floatX)
#       2 xsamples = np.asarray([[0]],dtype=floatX)
# ----> 3 print f1(xsamples,zsamples)
#       4 print f2(zsamples)
#
# NameError: name 'f1' is not defined

# %%
a = utilsT.sharedf( 50 )
b = utilsT.sharedf( np.asarray([1,2,3]) )

# %%
c = b + 5
fb = theano.function([], outputs=c)

# %%
fb()
# Out:
# array([ 6.,  7.,  8.], dtype=float32)
